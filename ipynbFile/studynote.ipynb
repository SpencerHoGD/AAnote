# %% [markdown]
# ## This is my studynote!

# %%
print(`hello world!`)

# %% [markdown]
# shebang:
# `#!/usr/bin/env python3`
# `# -*- encoding: utf-8 -*-`
#
# this is the first comment

# %% [markdown]
# - curly braces {}
# - parentheses ()
# - colon `:`
# - minus sign `-`
# - binary `0b`
# - octal `0o`
# - hexadecimal `0x`
# - underscore `_`
# - percentage `%`
# - multipliesb `*`
# - comma `,`
# - sequence type: list, str, tuple, bytes, has __getitem__(), __len__()

# %% [markdown]
# 3.1.1 numbers
# 3.1.2 strings
# 1. inclosed in single quotes or double quotes
# 3.1.3 lists

# %% [markdown]
# ## Format examples

# %%
print(`{0}, {1}, {2}`.format(`a`, `b`, `c`))
print(`{}, {}, {}`.format(`a`, `b`, `c`))
print(`{2}, {1}, {0}`.format(`a`, `b`, `c`))
print(`{0}{1}{0}`.format(`abra`, `cad`))

# %%
# print(`Coordinates: {latitude}, {longitude}`.format(latitude=`37.24N`, longitude=`-115.81W`))
coord = {`latitude`: `37.24N`, `longitude`: `-115.81W`}
print(`Coordinates: {latitude}, {longitude}`.format(**coord))

# %%
c = 3-5j
print(`The complex number {0} is formed from the real part{0.real} and the imaginary part {0.imag}.`.format(c))

# %%
class Point:
    def __init__(self, x, y):
        self.x, self.y = x, y
    def __str__(self):
        return `Point({self.x}, {self.y})`.format(self=self)
    

print(Point(4, 2))

# %%
coord = (3, 5)
print(`X: {0[0]}; Y: {0[1]}`.format(coord))
print(`X: {0}; Y: {1}`.format(*coord))

# %%
print(`{:<100}`.format(`left aligned`))
print(`{:->100}`.format(`right aligned`))
print(`{:^100}`.format(`centered`))
print(`{:*^100}`.format(`centered`))

# %%
print("int: {0:d}; hex: {0:x}; oct: {0:o}; bin: {0:b}".format(42))
print("int: {0:d}; hex: {0:#x}; oct: {0:#o}; bin: {0:#b}".format(42))

# %%
print(`{:,}`.format(1234567890))

# %%
points = 19
total = 22
print(`Correct answers: {:.2%}`.format(points/total))

# %%
import datetime
d = datetime.datetime(2019, 12, 1, 20,12,20)
print(`{:%Y-%m-%d %H:%M:%S}`.format(d))

# %%
for align, text in zip(`<^>`, [`left`, `center`, `right`]):
    print(`{0:{fill}{align}16}`.format(text, fill=align, align=align))

# %%
octets = [192, 168, 0, 1]
a = `{:02X}{:02X}{:02X}{:02X}`.format(*octets)
print(a)
print(int(a, 16))

# %%
width = 5
for num in range(5, 12):
    for base in `dXob`:
        print(`{0:{width}{base}}`.format(num, base=base, width=width), end=`  `)

# %%
from string import Template
s = Template(`$who likes $what`)
a = s.substitute(who=`Tim`, what=`kung pao`)
print(a)

# %%
import string
lts = string.ascii_letters
punc = string.punctuation
prtb = string.printable
print(lts)
print(punc)
print(prtb)

# %%
a, b = 0, 1
while a < 1000:
    print(a, end=',')
    a, b = b, a+b

# %%
x = int(input('Please enter an integer: '))
if x < 0:
    x = 0
    print(' Negative changed to zero')
elif x == 0:
    print('Zero')
elif x ==1:
    print('Single')
else:
    print('More')

# %%
a = ['Mary', 'had', 'a', 'little', 'lamb']
for i, v in enumerate(a):
    print(i, v)

# %%
knights = {'gallahad': 'the pure', 'robin': 'the brave'}
for k, v in knights.items():
    print(k, v)

# %%
questions = ['name', 'quest', 'favorite color']
answers = ['lancelot', 'the holy grail', 'blue']
for q, a in zip(questions, answers):
    print('What is you {}? It is {}.'.format(q, a))

# %%
for i in reversed(range(1, 10, 2)):
    print(i)

# %%
basket = ['apple', 'orange', 'apple', 'pear', 'orange', 'banana']
for f in sorted(set(basket)):
    print(f)

# %%
import math
raw_data = [56.2, float('NaN'), 51.7, 55.3, 52.5, float('NaN'), 47.8]
filtered_data = []
for value in raw_data:
    if not math.isnan(value):
        filtered_data.append(value)
        
print(filtered_data)

# %%
a = list(range(10))
print(a)

# %%
def fib(n):    # write Fibonacci series up to n
    """Print a Fibonacci series up to n."""
    a, b = 0, 1
    while a < n:
        print(a, end=' ')
        a, b = b, a+b
        
fib(20000)

# %%
def fib2(n):   #return Fibonacci series up to n
    """Return a list containing Fibonacci series up to n."""
    result = []
    a, b = 0, 1
    while a < n:
        result.append(a)
        a, b = b, a+b
    return result

fib2(200)

# %%
def ask_ok(prompt, retries=4, reminder='Please try again!'):
    while True:
        if ok in ('y', 'ye', 'yes'):
            return True
        if ok in ('n', 'nop', 'nope'):
            return False
        retries = retries - 1
        if retries < 0:
            raise ValueError('invalid user response')
        print(reminder)

# %%
def make_incrementor(n):
    return lambda x: x + n

f = make_incrementor(50)
f(40)

# %%
pairs = [(1, 'one'), (2, 'two'), (3, 'three'), (4, 'four')]
# pairs.sort(key=lambda pair: pair[1])
print(pairs)

# %%
class Complex:
    def __init__(self, realpart, imagpart):
        self.r = realpart
        self.i = imagpart

x = Complex(3.0, -4.5)
x.r, x.i

# %%
squares = [x**2 for x in range(10)]
print(squares)

# %%
vec = [-4, -2, 0, 2, 4]
# creat a new list with the values doubled
[x*2 for x in vec]
# filter the list to exclude negative numbers
[x for x in vec if x >= 0]
#apply a function to all the elements
[abs(x) for x in vec]
#call a method on each element
#create a list of 2-tuple like (number, square)
[(x, x**2) for x in range(6)]
#flatten a list using a listcomp with two 'for'
vec = [[1,2,3], [4,5,6], [7,8,9]]
[num for elem in vec for num in elem]

# %%
from math import pi
[str(round(pi, i)) for i in range(1, 6)]

# %%
import platform
system = platform.system()
# print(str(system))
print(system)

# %%
import tushare
print(tushare.__version__)

# %%
# 设置tushare pro的token并获取连接
import tushare as ts
import datetime
import pymysql

pro = ts.pro_api('74eabb1fce9fd5c317fd38477a465d0aa4eb167e0ee272be91631a0e')

# 设定获取日线行情的初始日期和终止日期，其中终止日期设定为昨天。
start_dt = '20191205'
time_temp = datetime.datetime.now() - datetime.timedelta(days=1)
end_dt = time_temp.strftime('%Y%m%d')
# 建立数据库连接,剔除已入库的部分
db = pymysql.connect(host='127.0.0.1', user='root', passwd='admin', db='stock', charset='utf8')
cursor = db.cursor()
# 设定需要获取数据的股票池
stock_pool = ['603912.SH','300666.SZ','300618.SZ','002049.SZ','300672.SZ']
total = len(stock_pool)
# 循环获取单个股票的日线行情
for i in range(len(stock_pool)):
    try:
        df = pro.daily(ts_code=stock_pool[i], start_date=start_dt, end_date=end_dt)
        # 打印进度
        print('Seq: ' + str(i+1) + ' of ' + str(total) + '   Code: ' + str(stock_pool[i]))

# %%
import tushare as ts


pro = ts.pro_api('74eabb1fce9fd5c317fd38477a465d0aa4eb167e0ee272be91631a0e')

# df = pro.query('trade_cal', exchange='', start_date='20191001', end_date='20191208', fields='exchange,cal_date,is_open,pretrade_date', is_open='0')

# df = ts.get_today_all()
# df1 = ts.get_hist_data('002717')
# df2 = pro.daily(ts_code='002717.SZ', start_date='20191101', end_date='20191218')


# data = pro.query('stock_basic', exchange='', list_status='L', fields='ts_code,symbol,name,area,industry,list_date')
# print(data)

df2.head(100)
# Out:
#       ts_code trade_date  open  high   low  close  pre_close  change  pct_chg  \
# 0   002717.SZ   20191206  4.51  4.93  4.51   4.83       4.51    0.32   7.0953
# 1   002717.SZ   20191205  4.41  4.53  4.40   4.51       4.41    0.10   2.2676
# 2   002717.SZ   20191204  4.39  4.43  4.38   4.41       4.38    0.03   0.6849
# 3   002717.SZ   20191203  4.32  4.42  4.31   4.38       4.32    0.06   1.3889
# 4   002717.SZ   20191202  4.37  4.37  4.32   4.32       4.38   -0.06  -1.3699
# 5   002717.SZ   20191129  4.44  4.45  4.36   4.38       4.44   -0.06  -1.3514
# 6   002717.SZ   20191128  4.48  4.50  4.43   4.44       4.50   -0.06  -1.3333
# 7   002717.SZ   20191127  4.51  4.51  4.47   4.50       4.52   -0.02  -0.4425
# 8   002717.SZ   20191126  4.52  4.53  4.48   4.52       4.51    0.01   0.2217
# 9   002717.SZ   20191125  4.54  4.54  4.48   4.51       4.52   -0.01  -0.2212
# 10  002717.SZ   20191122  4.52  4.55  4.49   4.52       4.55   -0.03  -0.6593
# 11  002717.SZ   20191121  4.55  4.56  4.49   4.55       4.55    0.00   0.0000
# 12  002717.SZ   20191120  4.60  4.61  4.54   4.55       4.60   -0.05  -1.0870
# 13  002717.SZ   20191119  4.62  4.63  4.59   4.60       4.59    0.01   0.2179
# 14  002717.SZ   20191118  4.63  4.64  4.57   4.59       4.62   -0.03  -0.6494
# 15  002717.SZ   20191115  4.70  4.70  4.61   4.62       4.68   -0.06  -1.2821
# 16  002717.SZ   20191114  4.67  4.73  4.59   4.68       4.67    0.01   0.2141
# 17  002717.SZ   20191113  4.72  4.72  4.65   4.67       4.68   -0.01  -0.2137
# 18  002717.SZ   20191112  4.74  4.74  4.60   4.68       4.64    0.04   0.8621
# 19  002717.SZ   20191111  4.61  4.69  4.52   4.64       4.62    0.02   0.4329
# 20  002717.SZ   20191108  4.67  4.68  4.61   4.62       4.67   -0.05  -1.0707
# 21  002717.SZ   20191107  4.68  4.69  4.65   4.67       4.68   -0.01  -0.2137
# 22  002717.SZ   20191106  4.71  4.71  4.65   4.68       4.70   -0.02  -0.4255
# 23  002717.SZ   20191105  4.71  4.72  4.68   4.70       4.71   -0.01  -0.2123
# 24  002717.SZ   20191104  4.71  4.73  4.70   4.71       4.73   -0.02  -0.4228
# 25  002717.SZ   20191101  4.72  4.73  4.70   4.73       4.70    0.03   0.6383
#
#           vol      amount
# 0   405614.51  192618.378
# 1   115328.65   51690.408
# 2    36909.54   16261.792
# 3    92431.72   40554.517
# 4    65496.85   28406.638
# 5    81471.50   35809.903
# 6    41507.90   18519.317
# 7    74550.25   33524.594
# 8   153354.23   68967.737
# 9    47650.08   21436.418
# 10  106646.22   48123.634
# 11   69012.20   31178.684
# 12   72150.00   32915.239
# 13   45949.94   21153.973
# 14   86260.54   39720.067
# 15   52823.18   24460.681
# 16  123557.45   57607.639
# 17   65771.04   30784.699
# 18  123632.82   57743.425
# 19  114619.34   52709.806
# 20   55320.04   25687.565
# 21   25963.98   12115.841
# 22  104591.45   48837.307
# 23   58410.19   27454.768
# 24  109654.50   51616.466
# 25   37247.45   17533.212
