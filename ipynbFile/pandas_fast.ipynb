# %%
import pandas as pd 
import timeit 
# from timeit import timeit as timeit

# %%
df1 = pd.read_csv('daily_2019.csv')
df1.head()

# %%
def func():
    normal_list=range(10000)
    L = [i**2 for i in normal_list]

timer1 = timeit.Timer("func()", setup="from __main__ import func")
print(timer1.timeit(number=10))

# %%
def func():
    pd.read_csv('daily_2019.csv')

timer1 = timeit.Timer("func()", setup="from __main__ import func")
print(timer1.timeit(number=10))

# %%
def func():
    pd.read_pickle('daily_2019.pkl')

timer1 = timeit.Timer("func()", setup="from __main__ import func")
print(timer1.timeit(number=10))

# %%
def func():
    pd.read_hdf('daily_2019.hdf', 'df')

timer1 = timeit.Timer("func()", setup="from __main__ import func")
print(timer1.timeit(number=10))

# %%
t1 = timeit.Timer('char in text', setup='text = "sample string"; char = "g"')
t1.timeit()

# %%
t1.repeat(10)

# %%
timeit.timeit('"-".join(map(str, range(100)))', number=10000)

# %%
timeit.timeit(lambda:pd.read_csv('daily_2019.csv'), number=10)
# Out:
# 5.786622767999688

# %%
timeit.timeit(lambda:pd.read_pickle('daily_2019.pkl'), number=10)

# %%
s1 = pd.Series(list(range(1,7)), index=pd.date_range('20130102', periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
timeit.timeit(lambda:pd.read_hdf('daily_2019.hdf', 'df'), number=10)
